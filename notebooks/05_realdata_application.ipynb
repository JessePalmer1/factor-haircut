# %% [markdown]
# # 05 — Real-data application (Chen–Zimmermann)
#
# **Phase 5 companion notebook.**
#
# Goals:
# 1. Load 212 published factors via `src/data.py` (openassetpricing).
# 2. Apply BY correction across several plausible m values (300, 600, 1000+).
# 3. Compute haircut and implied threshold per factor.
# 4. Report headline: fraction of factors that survive a multiplicity-adjusted bar.
#
# Treat sensitivity to m as a result in itself — how robust is survival to your
# assumption about how much unpublished searching happened?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys; sys.path.insert(0, '..')

from src.data import load_published_factors, filter_by_predictability, compute_pvals
from src.corrections import benjamini_yekutieli, implied_threshold, haircut

rng = np.random.default_rng(4)

# %%
# TODO: load data, apply corrections, build results table
