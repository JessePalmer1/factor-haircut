# %% [markdown]
# # 04 — Deflated Sharpe Ratio validation
#
# **Phase 4 companion notebook.**
#
# Goals:
# 1. Implement and validate `psr()` and `deflated_sharpe()` from `src/dsr.py`.
# 2. Generate N zero-skill strategies; confirm realized max Sharpe tracks SR*.
# 3. Confirm a borderline strategy returns DSR ≈ 0.5.
# 4. Explicitly connect SR* (Gumbel order-statistic) to E[max t_i] ~ sqrt(2 ln m).

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys; sys.path.insert(0, '..')

from src.dsr import psr, deflated_sharpe, dsr_benchmark

rng = np.random.default_rng(3)

# %%
# TODO: validation experiments
