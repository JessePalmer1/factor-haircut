# %% [markdown]
# # 01 — Theory sanity checks
#
# **Phase 1 companion notebook.**
#
# Goals:
# 1. Numerically confirm `E[max_i t_i] ≈ sqrt(2 ln m)` by simulation.
# 2. Verify the five-p-value worked examples for all four corrections.
# 3. Build intuition for the FWER/FDR distinction via small examples.
#
# No production code here — exploration only. Finalized logic goes in `src/`.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

rng = np.random.default_rng(0)

# %% [markdown]
# ## 1. Expected maximum of m standard-normal draws
#
# Theory: `E[max_i t_i] ≈ sqrt(2 ln m)` for m i.i.d. N(0,1).
#
# Tabulate for m ∈ {10, 50, 100, 300, 1000} and compare to simulation.

# %%
# TODO: simulate and tabulate

# %% [markdown]
# ## 2. Five-p-value worked example
#
# Apply all four corrections by hand and verify with statsmodels.

# %%
# TODO: five p-values, manual step-through, assert vs statsmodels

# %% [markdown]
# ## 3. FWER vs FDR intuition
#
# Small simulation: m=20 tests, 5 truly non-null. Compare false-positive behavior.

# %%
# TODO: simulate
